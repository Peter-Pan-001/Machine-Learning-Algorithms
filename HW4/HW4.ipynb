# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

# %% [markdown]
# ## Problem 1 (a)

# %%
file = open('./hw4_data/TeamNames.txt', 'r') 
mapping = np.array(file.read().split('\n'))
score = pd.read_csv('./hw4_data/CFB2018_scores.csv', header = None)

# %%
score.loc[:,2].max()
# Out:
# 767

# %%
score = np.array(score)
M = np.zeros(shape = (767,767))

for i in range(len(score)):
    point_frac_A = score[i][1] / (score[i][1] + score[i][3])
    point_frac_B = score[i][3] / (score[i][1] + score[i][3])
    M[score[i][0] - 1][score[i][0] - 1] += point_frac_A
    M[score[i][2] - 1][score[i][2] - 1] += point_frac_B
    M[score[i][0] - 1][score[i][2] - 1] += point_frac_B
    M[score[i][2] - 1][score[i][0] - 1] += point_frac_A
    if score[i][1] > score[i][3]:
        M[score[i][0] - 1][score[i][0] - 1] += 1
        M[score[i][2] - 1][score[i][0] - 1] += 1
    elif score[i][1] < score[i][3]:
        M[score[i][0] - 1][score[i][2] - 1] += 1
        M[score[i][2] - 1][score[i][2] - 1] += 1

row_sum = np.sum(M, axis = 1)
for i in range(767):
    M[i,:] /= row_sum[i]
M
# Out:
# array([[0.53903457, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.37886441, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.46198924, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.49844282, 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.5105451 ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.41617174]])

# %%
w = np.array([1/767] * 767).reshape(1,-1)
w_store = []

for i in range(10000):
    w = np.dot(w, M)
    w_store.append(w)

top = []
for i in [9,99,999,9999]:
    top_list = mapping[np.argsort(w_store[i]).reshape(-1)[::-1][:25]]
    w_list = np.sort(w_store[i]).reshape(-1)[::-1][:25]
    top.extend([top_list, w_list])

# %%
top_df = pd.DataFrame(np.array(top).T)
top_df.columns = ['t=10_name', 't=10_w', 't=100_name', 't=100_w','t=1000_name', 't=1000_w','t=10000_name', 't=10000_w']
top_df
# Out:
#              t=10_name                 t=10_w          t=100_name  \
# 0   Mary Hardin-Baylor   0.017639798654528322  Mary Hardin-Baylor
# 1              Clemson   0.014032441637353173             Clemson
# 2          Mount Union   0.012248981016145988             Alabama
# 3          Morningside   0.011157063857289026         Mount Union
# 4      North Dakota St   0.010944365819628456        St John's MN
# 5          Valdosta St   0.010342902815416123         Morningside
# 6         St John's MN   0.009911909116771318         Valdosta St
# 7              Alabama   0.009898174746709568     North Dakota St
# 8        UW-Whitewater   0.009682759468654595             Georgia
# 9            Ferris St   0.009671185502235715          Ohio State
# 10       Johns Hopkins   0.009448335744716391          Notre Dame
# 11        Brockport St   0.006858614514892717       UW-Whitewater
# 12           Princeton    0.00681131042361692           Ferris St
# 13     Minn St-Mankato   0.006734949268700698            Oklahoma
# 14      Benedictine KS   0.006550519558662781       Johns Hopkins
# 15     Kansas Wesleyan   0.005917028936663904           Texas A&M
# 16          Ohio State  0.0058441546927107705                 LSU
# 17           Marian IN   0.005659183443190517             Florida
# 18           Bethel MN   0.005654955614924589            Kentucky
# 19          Muhlenberg  0.0055395687370953265               Texas
# 20         Tarleton St   0.005476268071983852            Michigan
# 21    Ouachita Baptist   0.005417983561774517            Syracuse
# 22             Georgia   0.005409007367184307     Central Florida
# 23          Notre Dame   0.005299447683292239       Washington St
# 24       Notre Dame OH   0.005248646935339546          Washington
#
#                   t=100_w         t=1000_name              t=1000_w  \
# 0     0.06084733790627028             Clemson   0.09737623073336274
# 1    0.048802595798256534             Alabama  0.053666225514063706
# 2    0.027211276643123075             Georgia  0.023190572765959032
# 3    0.021395762698260042          Ohio State  0.022592308391066147
# 4    0.014651160971966243          Notre Dame  0.022336695739034535
# 5    0.013446393342868639            Oklahoma   0.01911324531760728
# 6    0.012792027097969111           Texas A&M  0.016574875847361864
# 7    0.012501615196745853                 LSU  0.015151626340862884
# 8     0.01187677413408951             Florida  0.015051145870663014
# 9    0.011871182314592115     North Dakota St  0.014735609657188975
# 10   0.011582831142212547            Kentucky  0.014335475698743865
# 11    0.01148113937346632               Texas  0.013913550737452067
# 12   0.011187132520245505            Michigan   0.01378199007696958
# 13   0.010029146645479738            Syracuse  0.013223378404808563
# 14   0.009890343475655585     Central Florida  0.012440910855725313
# 15   0.008445909256987582  Mary Hardin-Baylor   0.01188443833649618
# 16   0.007799736645867695          Washington  0.011316887690949965
# 17   0.007781991712585718       Washington St  0.011222327877578212
# 18   0.007376338661966822          Penn State  0.010118464424667675
# 19   0.007277594380094606              Auburn   0.00997655893197494
# 20   0.007192811085786144            Missouri  0.009721857956462932
# 21   0.006816281485482184                Iowa  0.009647621732328611
# 22   0.006537513141412551        Northwestern  0.009192264888459829
# 23  0.0063803646688843675       West Virginia  0.009174209916387037
# 24  0.0062689999401099004           Fresno St  0.008900919455990374
#
#        t=10000_name             t=10000_w
# 0           Clemson   0.10388204469882503
# 1           Alabama    0.0572230675145033
# 2           Georgia  0.024715660707430375
# 3        Ohio State   0.02405528557407886
# 4        Notre Dame  0.023797410121030826
# 5          Oklahoma  0.020351875293171784
# 6         Texas A&M  0.017669361605791477
# 7               LSU  0.016144325324043834
# 8           Florida  0.016035701568438848
# 9   North Dakota St  0.015301920890875913
# 10         Kentucky  0.015276328923616562
# 11            Texas   0.01481665783261277
# 12         Michigan  0.014678833415603632
# 13         Syracuse  0.014091358071000325
# 14  Central Florida  0.013244348718820102
# 15       Washington  0.012022265442175894
# 16    Washington St  0.011907772583628498
# 17       Penn State  0.010773021766217066
# 18           Auburn  0.010624306433950879
# 19         Missouri  0.010358632953833817
# 20             Iowa   0.01025920155927499
# 21     Northwestern  0.009783840168456147
# 22    West Virginia  0.009763893808230424
# 23        Fresno St  0.009452107919709962
# 24   South Carolina  0.008896472297894926

# %% [markdown]
# ## Problem 1 (b)

# %%
eigenvalue, eigenvector = np.linalg.eig(M.T)
vector = eigenvector[:, np.argmax(eigenvalue)]
w_stationary = (vector / np.sum(vector)).reshape(-1)

# %%
w = np.array([1/767] * 767).reshape(1,-1)
l1_store = []

for i in range(10000):
    w = np.dot(w, M)
    l1_store.append(np.sum(np.abs(w - w_stationary)))

# %%
num = (np.array(range(10000)) + 1).reshape(-1,1)
distance = np.array(l1_store).reshape(-1,1)
plot = np.append(num, distance, axis = 1)
plot_df = pd.DataFrame(plot, columns = ['t', 'Norm1-distance'])
plot_df['t'] = plot_df['t'].astype(int)

# %%
fig, ax = plt.subplots(1, 1, figsize = (20,10))
_ = ax.plot(plot_df.loc[:,'t'], plot_df.loc[:,'Norm1-distance'])
_ = ax.legend()
_ = ax.set_xlabel('Iteration')
_ = ax.set_ylabel('Norm1-distance')

# %% [markdown]
# ## Problem 2 (a)

# %%
file = open('./hw4_data/nyt_data.txt', 'r') 
documents = np.array(file.read().split('\n'))

# %%
len(documents)
# Out:
# 8448

# %%
documents[-1]
# Out:
# ''

# %%
X = np.zeros(shape = (3012, 8847))
W = np.zeros(shape = (3012, 25))
H = np.zeros(shape = (25, 8847))

# initialization
for i in range(len(documents) - 1):
    document = documents[i]
    word_count = document.split(',')
    for j in range(len(word_count)):
        temp = word_count[j].split(':')
        word = int(temp[0].strip())
        count = int(temp[1].strip())
        X[word-1][i] += count

for i in range(W.shape[0]):
    for j in range(W.shape[1]):
        W[i][j] = np.random.uniform(1,2)

for i in range(H.shape[0]):
    for j in range(H.shape[1]):
        H[i][j] = np.random.uniform(1,2)

# %%
loss_list = []
for i in range(100):
    H = H * np.dot(W.T,(X/(np.dot(W,H) + 10**(-16))))/(np.sum(W, axis = 0).reshape(-1,1) + 10**(-16))
    W = W * np.dot((X/(np.dot(W,H) + 10**(-16))),H.T)/(np.sum(H, axis = 1).reshape(1,-1) + 10**(-16))
    loss = np.sum(X * np.log(1/(np.dot(W,H) + 10**(-16))) + np.dot(W,H))
    loss_list.append(loss)

# %%
num = (np.array(range(100)) + 1).reshape(-1,1)
loss_array = np.array(loss_list).reshape(-1,1)
plot = np.append(num, loss_array, axis = 1)
plot_df = pd.DataFrame(plot, columns = ['t', 'Objective'])
plot_df['t'] = plot_df['t'].astype(int)

# %%
fig, ax = plt.subplots(1, 1, figsize = (20,10))
_ = ax.plot(plot_df.loc[:,'t'], plot_df.loc[:,'Objective'])
_ = ax.legend()
_ = ax.set_xlabel('Iteration')
_ = ax.set_ylabel('Objective')

# %% [markdown]
# ## Problem 2 (b)

# %%
file = open('./hw4_data/nyt_vocab.dat', 'r') 
names = np.array(file.read().split('\n'))[:-1]

# %%
len(names)
# Out:
# 3012

# %%
W_norm = W / np.sum(W, axis = 0)

# %%
name_list = []
weight_list = []
for c in range(W.shape[1]):
    temp = W_norm[:, c].reshape(-1)
    name = names[np.argsort(temp)[::-1][:10]]
    weight = np.sort(temp)[::-1][:10]
    name_list.append(name)
    weight_list.append(weight)

# %%
for i in range(W.shape[1]):
    print('topic {}\n'.format(i+1))
    df = pd.DataFrame(np.append(name_list[i].reshape(-1,1), weight_list[i].reshape(-1,1), axis = 1),\
                     columns = ['name', 'weight'])
    print(df)
    print('\n')
# Out:
# topic 1
#
#             name                weight
# 0       american   0.01875578319518201
# 1            war  0.018533036560898736
# 2         states  0.017675255567869315
# 3       military  0.016430384112137247
# 4          force  0.011762109294462213
# 5        country   0.01139001533944999
# 6         attack  0.011196285154733955
# 7     government  0.010846309893328639
# 8       official  0.009761466335914515
# 9  international  0.008781336915389522
#
#
# topic 2
#
#      name                weight
# 0   water  0.026645084653285404
# 1   pound  0.013295649853228418
# 2    heat  0.010217763907917453
# 3     oil  0.009429851200891291
# 4     add  0.008992886314157166
# 5    inch  0.008914651440800943
# 6   plant  0.008895494718428425
# 7  minute  0.008677238580684327
# 8     dry   0.00862887200488687
# 9     cut  0.008423131602071839
#
#
# topic 3
#
#        name                weight
# 0   percent  0.025202186698369787
# 1  increase   0.01876707637404489
# 2      cost  0.013494336764283936
# 3      rate  0.010230491826783492
# 4   economy  0.009801166925575968
# 5  economic  0.009672092056115397
# 6      rise  0.009186588310786593
# 7       low  0.008543036900941952
# 8    growth   0.00826260000666902
# 9    number   0.00815223094831459
#
#
# topic 4
#
#            name                weight
# 0      building  0.023379842753433026
# 1          city  0.021816872844874248
# 2          area  0.015154602452550096
# 3         build    0.0150838345370662
# 4      resident  0.014207408882025697
# 5         house  0.011401348533087342
# 6       project   0.01121270269264198
# 7          site  0.009271089180133972
# 8  construction  0.009130547664433164
# 9     community  0.008494972846245107
#
#
# topic 5
#
#         name                weight
# 0     school  0.046475642694493835
# 1    student  0.030863451675244104
# 2    program   0.01640693184995472
# 3      class  0.016258303134786836
# 4      child  0.014873364042724034
# 5    college  0.014437570043700616
# 6  education  0.013990195576492335
# 7    teacher  0.012038027440706629
# 8  community   0.01122978334068927
# 9     parent  0.010135967972538565
#
#
# topic 6
#
#       name                weight
# 0     game  0.020020032530443977
# 1     team   0.01750087817177614
# 2     play  0.017361444548666338
# 3      win  0.014490512658986198
# 4   player  0.013688566464884179
# 5   season  0.013432993073328828
# 6   second  0.011951293736934399
# 7  victory  0.008598407350758314
# 8    score  0.007957202647629487
# 9     lose  0.007874823188448676
#
#
# topic 7
#
#         name                weight
# 0      price  0.021092402578436087
# 1    percent  0.019477408566171483
# 2     market  0.019415176303237837
# 3       rate    0.0166270911349124
# 4       bond  0.014144293677516647
# 5   interest  0.013741530179040269
# 6      point  0.013100498012537157
# 7       rise    0.0130447354484861
# 8  yesterday  0.012454642754820798
# 9       fall  0.012212759286673674
#
#
# topic 8
#
#         name                 weight
# 0   american    0.01066036621606624
# 1      world    0.00933326070407352
# 2    history    0.00859973998538557
# 3      great   0.008022249292434972
# 4    century   0.007021286090606649
# 5       view   0.006703679307783198
# 6       life   0.005723908316862314
# 7  important   0.005660487078855891
# 8  different   0.005620540887211432
# 9      study  0.0054494952644898575
#
#
# topic 9
#
#      name                weight
# 0  family   0.01401652454832139
# 1    life  0.013281644235001428
# 2   child  0.013142018646202052
# 3    live   0.01265126977699546
# 4    home   0.01260318485289585
# 5  friend  0.011728841499839006
# 6     man  0.010547694812498253
# 7    tell  0.010384697172480214
# 8   young  0.010355833526214936
# 9     old  0.010076786100223214
#
#
# topic 10
#
#        name                weight
# 0       ask  0.017300750635209364
# 1  question  0.013732497318078875
# 2      tell  0.013110710193618567
# 3     thing  0.012783683117193755
# 4     speak  0.008744303770998942
# 5      news  0.008476833096923122
# 6      feel  0.007782818397104404
# 7      word  0.007188010273410159
# 8      talk  0.007000942943791913
# 9    answer  0.006704886383272552
#
#
# topic 11
#
#           name                weight
# 0        music  0.023858772864030466
# 1         play  0.018533466549100087
# 2  performance  0.014616186368047483
# 3     audience  0.011580418207210156
# 4   production  0.011147058320901805
# 5      perform  0.010555938010849942
# 6        dance  0.010067577311205896
# 7        stage  0.010029769538640683
# 8         song  0.009954712094714267
# 9      theater   0.00984341274306194
#
#
# topic 12
#
#         name                weight
# 0     health  0.015603889552175496
# 1       drug  0.013621529203553936
# 2     doctor  0.011916257880613627
# 3      study  0.011531375577689094
# 4    medical  0.011109358784732067
# 5    patient   0.01020264497240679
# 6       care  0.009676261113732517
# 7      cause  0.009584517077483298
# 8  treatment    0.0094255426060976
# 9     report  0.008278549811811278
#
#
# topic 13
#
#          name                weight
# 0    campaign  0.017446152203780728
# 1       state  0.016211982377606137
# 2        vote  0.016001315957144612
# 3  republican   0.01571471420204867
# 4        bill  0.013609400801070426
# 5   candidate   0.01160690025399582
# 6      budget  0.011420523927888325
# 7         tax  0.010118675358116435
# 8   democrats   0.00959893625228615
# 9  democratic  0.009327260408673993
#
#
# topic 14
#
#       name                 weight
# 0     wear    0.01093923940953526
# 1    white   0.008191861684634498
# 2    color   0.007920330339583352
# 3    light    0.00720499222212233
# 4    stand   0.006627343618433601
# 5     wall   0.006615575239908358
# 6     blue   0.006505421751636813
# 7    black   0.006328302794953897
# 8  fashion   0.006166032756690524
# 9    image  0.0058686312273403774
#
#
# topic 15
#
#         name                 weight
# 0   official   0.017991795793600843
# 1       plan   0.013668801273656878
# 2    meeting   0.009925046625413922
# 3   decision   0.008842340784319048
# 4   announce   0.008565599068502622
# 5     member   0.008247026069482568
# 6       meet   0.008125409264259746
# 7       move   0.007206750486268209
# 8  agreement   0.006750939402124245
# 9     expect  0.0067263427940908406
#
#
# topic 16
#
#       name                weight
# 0      car  0.023692706290393932
# 1     hour   0.01280709914983431
# 2   travel  0.012120468219487236
# 3     mile    0.0118845636641885
# 4    train  0.011474945079330697
# 5    hotel  0.010393281800669738
# 6   driver  0.010380802754547249
# 7     trip  0.009947307373886709
# 8   flight  0.009104983388622598
# 9  station  0.008970346825222937
#
#
# topic 17
#
#       name                weight
# 0      law  0.021451958360068066
# 1    court  0.014743222420049957
# 2     case  0.014687013241721383
# 3     rule  0.013005668416700146
# 4    state  0.012958022794190836
# 5   lawyer  0.011972099963586313
# 6    legal  0.010920978075548001
# 7     file  0.009427378271664824
# 8    issue  0.009421342353356668
# 9  require  0.008993929992465819
#
#
# topic 18
#
#          name                weight
# 0   political   0.02831806450078254
# 1      leader   0.01966000659879132
# 2  government  0.015082753981875498
# 3     country   0.01284663678354175
# 4       power  0.011068179973010954
# 5       group  0.010252203657166767
# 6       party  0.009952404263908154
# 7    election   0.00960656483818369
# 8     support  0.009536118987207961
# 9      member   0.00890087610078636
#
#
# topic 19
#
#         name                weight
# 0    company   0.04475907100394294
# 1   business  0.019367243236049218
# 2       sell  0.015717187904774173
# 3     market  0.014986932498382736
# 4      share  0.014334744295558042
# 5  executive  0.014332618142292466
# 6       sale   0.01366267226682505
# 7   industry   0.01193775882553691
# 8        buy  0.011796824019333737
# 9      stock  0.011546428169427634
#
#
# topic 20
#
#           name                weight
# 0     computer  0.017105978585563862
# 1       system   0.01227752626744585
# 2   technology  0.012208450031489033
# 3      program   0.00888284785337084
# 4   television  0.008406334330246651
# 5      company  0.008275091213430152
# 6      network  0.008173219415345559
# 7     internet  0.007831642180412771
# 8  information   0.00776161256017757
# 9         site  0.007383258491579957
#
#
# topic 21
#
#           name                weight
# 0          art  0.018776527624947293
# 1        store   0.01598271906741728
# 2       artist   0.01354654662890618
# 3       museum   0.01230989713513436
# 4         open   0.01182249407807245
# 5         shop  0.010984338986412436
# 6   exhibition  0.010680023608269725
# 7   collection  0.009869595009651405
# 8         sell  0.009767581745803099
# 9  information  0.009632180379050104
#
#
# topic 22
#
#             name                weight
# 0         police  0.025168137514920537
# 1         charge  0.019905414608379253
# 2        officer  0.013692856150994427
# 3            man  0.012890014101701893
# 4           case  0.012199497010530684
# 5          crime  0.011805452352928235
# 6  investigation  0.011576303566207268
# 7         arrest  0.011438898915703759
# 8          trial  0.011197483262427258
# 9       official  0.010063168863363253
#
#
# topic 23
#
#         name                weight
# 0       book  0.022040109233146796
# 1     editor  0.019570951290758663
# 2      write   0.01908901391819921
# 3      story   0.01537804824719716
# 4       life  0.012788285305490935
# 5       film  0.012684791573773203
# 6     writer   0.01247944935099189
# 7  character  0.012028845711303067
# 8      movie  0.010881237593109704
# 9        man  0.009815985014807821
#
#
# topic 24
#
#         name                weight
# 0  president  0.039654868045702514
# 1        mrs  0.036186138400834886
# 2     father  0.032901280209098285
# 3   graduate  0.027806732696622614
# 4        son   0.02664763705863222
# 5     retire   0.02585029425508013
# 6       vice  0.024729933712378565
# 7   director  0.024252801495516306
# 8       name  0.021536614973843942
# 9   daughter  0.021124897051139336
#
#
# topic 25
#
#          name                weight
# 0        food   0.02023373402274714
# 1       table  0.018904473701587876
# 2  restaurant  0.018307274876599673
# 3      dinner  0.015536798888814577
# 4         eat  0.013776101871187258
# 5       serve  0.012841569585509138
# 6        room  0.011263778134780345
# 7       drink  0.010394013061046025
# 8       taste  0.009997990880540108
# 9       lunch  0.009351526100344487
